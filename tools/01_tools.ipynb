# %%
from langchain_community.tools import DuckDuckGoSearchRun
from langchain_core.tools import tool

# %%
search = DuckDuckGoSearchRun()
ans = search.invoke("iran vs usa")
ans
# Out:
# "The Arab Posts / / World /IranvsUSA: It’s tough to focus on just football ...IranvsUSA: It’s tough to focus on just football Winner ofIranvsUSAin Group B on Tuesday will progress to World Cup last 16; US Soccer Federation showed support of protests inIranby not using ... Sports Mole previews Tuesday's World Cup clash betweenIranandUSA, including predictions, team news and possible lineups. TheIranvsUSAmatch will be broadcast live on Sports18 and Sports18 HD TV channels in India and both Jio Cinema ’ s app and website can watch ... ...Iranwere team B and theUSA... And just under a quarter century ago, FIFA hosted a pre-match routine forIranvsUSAand felt it was sufficient."

# %%
from langchain_community.tools import ShellTool

# %%
shell = ShellTool()
sll = shell.invoke('whoami')
sll
# Out:
# Executing command:
#  whoami
# c:\Users\hp\Desktop\AI\genAI-basics\.venv\Lib\site-packages\langchain_community\tools\shell\tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(
# 'tarun\\hp\r\n'

# %%
def multiply(a, b):
    """multiply the two number"""
    return a*b

# %%
def multiply(a:int, b:int) -> int:
    """multiply the two number"""
    return a*b

# %%
@tool 
def multiply(a:int, b:int) -> int:
    """multiply the two number"""
    return a*b

# %%
tool = multiply.invoke({'a':4, 'b':4})

# %%
tool
# Out:
# 16

# %%
print(multiply.name)
multiply.args
multiply.description
multiply.args_schema.model_json_schema()
# Out:
# multiply
# {'description': 'multiply the two number',
#  'properties': {'a': {'title': 'A', 'type': 'integer'},
#   'b': {'title': 'B', 'type': 'integer'}},
#  'required': ['a', 'b'],
#  'title': 'multiply',
#  'type': 'object'}
